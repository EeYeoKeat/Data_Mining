# %%
import pandas as pd
data = pd.read_html('https://en.wikipedia.org/wiki/Avengers:_Endgame')

# %%
print(f'Extracted {len(data)} table/s')
data[0]
# Out:
# Extracted 23 table/s
#             Avengers: Endgame                                Avengers: Endgame.1
# 0   Theatrical release poster                          Theatrical release poster
# 1                 Directed by                             Anthony RussoJoe Russo
# 2                 Produced by                                        Kevin Feige
# 3               Screenplay by                  Christopher MarkusStephen McFeely
# 4                    Based on                  The Avengersby Stan LeeJack Kirby
# 5                    Starring  Robert Downey Jr. Chris Evans Mark Ruffalo Chr...
# 6                    Music by                                     Alan Silvestri
# 7              Cinematography                                      Trent Opaloch
# 8                   Edited by                       Jeffrey Ford Matthew Schmidt
# 9           Productioncompany                                     Marvel Studios
# ...

# %%
data
# Out:
# [            Avengers: Endgame                                Avengers: Endgame.1
#  0   Theatrical release poster                          Theatrical release poster
#  1                 Directed by                             Anthony RussoJoe Russo
#  2                 Produced by                                        Kevin Feige
#  3               Screenplay by                  Christopher MarkusStephen McFeely
#  4                    Based on                  The Avengersby Stan LeeJack Kirby
#  5                    Starring  Robert Downey Jr. Chris Evans Mark Ruffalo Chr...
#  6                    Music by                                     Alan Silvestri
#  7              Cinematography                                      Trent Opaloch
#  8                   Edited by                       Jeffrey Ford Matthew Schmidt
#  9           Productioncompany                                     Marvel Studios
# ...

# %%
data[1]
# Out:
#                         Award    Date of ceremony  ...     Result Ref(s)
# 0       Golden Trailer Awards        May 29, 2019  ...        Won  [204]
# 1       Golden Trailer Awards        May 29, 2019  ...  Nominated  [204]
# 2       Golden Trailer Awards        May 29, 2019  ...  Nominated  [204]
# 3       Golden Trailer Awards        May 29, 2019  ...        Won  [204]
# 4       Golden Trailer Awards        May 29, 2019  ...  Nominated  [204]
# 5       Golden Trailer Awards        May 29, 2019  ...  Nominated  [204]
# 6       MTV Movie & TV Awards       June 17, 2019  ...        Won  [205]
# 7       MTV Movie & TV Awards       June 17, 2019  ...        Won  [205]
# 8       MTV Movie & TV Awards       June 17, 2019  ...        Won  [205]
# 9       MTV Movie & TV Awards       June 17, 2019  ...  Nominated  [205]
# 10         Teen Choice Awards     August 11, 2019  ...        Won  [206]
# 11         Teen Choice Awards     August 11, 2019  ...        Won  [206]
# ...

# %%
import requests
movie = requests.get('https://en.wikipedia.org/wiki/Avengers:_Endgame')
print(movie.status_code, movie.reason, len(movie.text))
print(movie.text[0:500])
# Out:
# 200 OK 607321
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Avengers: Endgame - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Avengers:_Endgame","wgTitle":"Avengers: Endgame","wgCurRevisionId":924263318,"wgRevisionId":924263318,"wgArticleId":44254295,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserG
